# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from sklearn.cluster import KMeans

# %%
img = cv2.imread("C:\\Users\\USER\\Downloads\\colorful_image.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (1080, 1000, 3)

# %%
img2 = img

# %%
img = img.reshape(-1,3)

# %%
img.shape
# Out:
# (1080000, 3)

# %%
#extracting 3 dominant colors from image
km = KMeans(n_clusters = 3)

# %%
km.fit(img)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
arr = np.zeros((100,100,3),dtype = 'int')
arr[:,:,:] = centres[2]
plt.imshow(arr)

# %%
centres = km.cluster_centers_
centres.shape
# Out:
# (3, 3)

# %%
labels = np.array(km.labels_, dtype = 'int')

# %%
new_image = np.zeros((1080000,3),dtype = 'int')

# %%
for i in range(img.shape[0]):
    new_image[i] =  centres[km.labels_[i]]

# %%
new_image = new_image.reshape((1080,1000,3))

# %%
plt.imshow(new_image)

# %%
kmeans = KMeans(n_clusters = 7)
kmeans.fit(img2)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=7, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
centers = kmeans.cluster_centers_

centers = np.array(centers,'uint8')

# %%
centers.shape
# Out:
# (7, 3)
